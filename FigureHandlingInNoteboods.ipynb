# %% [markdown]
# # Figure Handling in Jupyter NoteBooks

# %%
import matplotlib.pyplot as plt
from IPython.display import Image
import matplotlib.image as mpimg

# %% [markdown]
# #### Direct with markdown

# %% [markdown]
# ![This is the title of the figure](img/FireFriction.png)

# %% [markdown]
# #### Direct in HTML like style

# %% [markdown]
# ##### Schematic drwawig of the model <img src="img/FireFriction.png" style="width:600px">

# %% [markdown]
# #### Using Python and Matplotlib

# %%
image = mpimg.imread("img/FireFriction.png")
plt.figure(figsize=(12, 12))
plt.imshow(image)
plt.axis('off')
plt.show()
